# %% [markdown]
# # Insight 1

# %% [markdown]
# [https://indolem.github.io/](https://indolem.github.io/)

# %% [markdown]
# # Pipeline

# %% [markdown]
# # Insight 2

# %% [markdown]
# # Referensi

# %% [markdown]
# https://indolem.github.io (Diakses Kamis, 23 April 2026)
